# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalcjha/abustub-rs/blob/main/running_cuda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt -y purge nvidia-cuda-toolkit || true
# !sudo apt -y autoremove || true
# !pip install -U nvidia-cuda-nvcc-cu12
